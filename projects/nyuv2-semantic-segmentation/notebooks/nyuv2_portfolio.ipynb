# %% [markdown]
# # NYUv2 semantic segmentation portfolio notebook
#
# ## Goal
# - Rebuild an RGB-D semantic segmentation project with public NYUv2 data
# - Keep the README comparison axes reproducible in the notebook
#
# ## Data source
# - NYU Depth V2: https://cs.nyu.edu/~fergus/datasets/nyu_depth_v2.html
#
# ## Publication note
# - No course handout, no Google Drive path, no private checkpoint files are included

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

from src.dataset import describe_layout, list_samples

DATA_ROOT = Path('../data/raw/nyuv2').resolve()
print(describe_layout(DATA_ROOT))
print(list_samples(DATA_ROOT, 'train')[:5])

# %%
# TODO:
# 1. define an RGB-only baseline
# 2. define an RGB + depth model
# 3. compare with mIoU
# 4. export qualitative examples for the README

# %% [markdown]
# ## README checklist
# - mIoU
# - RGB-only vs RGB+depth comparison
# - depth-noise failure cases
# - wall / floor / furniture qualitative review
