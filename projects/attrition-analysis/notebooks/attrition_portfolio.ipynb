# %% [markdown]
# # Attrition analysis portfolio notebook
#
# ## Goal
# - Rebuild the attrition analysis with public HR data
# - Keep the same discussion points as the README
#
# ## Data source
# - IBM HR Analytics Employee Attrition & Performance public sample
#
# ## Publication note
# - No private CSV, no course-only files, no employee identifiers beyond the public sample

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

from src.prepare_data import available_columns, encode_attrition, load_attrition_csv, quick_summary

DATA_PATH = Path('../data/raw/attrition.csv').resolve()
df = load_attrition_csv(DATA_PATH)
df = encode_attrition(df)
print(available_columns(df))
print(quick_summary(df))

# %%
# TODO:
# 1. overall attrition rate
# 2. attrition by job role, job level, overtime, promotion interval
# 3. export three interview-ready findings to the README

# %% [markdown]
# ## README checklist
# - overall attrition rate
# - high-risk job role
# - job level skew
# - overtime / promotion as supporting factors
